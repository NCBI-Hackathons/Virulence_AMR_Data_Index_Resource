# %%
import pandas as pd

# %%
meta = pd.read_csv('../target_srr_metadata.csv')

# %%
meta
# Out:
#               acc assay_type                         center_name consent  \
# 0      SRR7658778        WGS               ROBERT KOCH INSTITUTE  public
# 1      SRR7658860        WGS               ROBERT KOCH INSTITUTE  public
# 2      SRR6291251        WGS       UNIVERSITY OF TEXAS AT DALLAS  public
# 3      SRR8643180        WGS                  MURDOCH UNIVERSITY  public
# 4      SRR8643250        WGS                  MURDOCH UNIVERSITY  public
# ...           ...        ...                                 ...     ...
# 12200  SRR1815818        WGS                            UCD-100K  public
# 12201  SRR1815822        WGS                            UCD-100K  public
# 12202  ERR3054170        WGS       UNIVERSITY HOSPITAL TUEBINGEN  public
# 12203  ERR2008113        WGS  HOSPITAL UNIVERSITARI DE BELLVITGE  public
# 12204   SRR980579        WGS             UNIVERSITY OF MELBOURNE  public
#
#        experiment     sample_name           instrument librarylayout  \
# 0      SRX4520536          UW1485  Illumina HiSeq 2500        PAIRED
# 1      SRX4520454         UW14000       Illumina MiSeq        PAIRED
# 2      SRX3392346   WGS Day 1 WT3  Illumina HiSeq 2500        PAIRED
# 3      SRX5441529            DBC3          NextSeq 500        PAIRED
# 4      SRX5441459            AAB2          NextSeq 500        PAIRED
# ...           ...             ...                  ...           ...
# 12200   SRX888190        BCW_3740  Illumina HiSeq 2500        PAIRED
# 12201   SRX888194        BCW_3745  Illumina HiSeq 2500        PAIRED
# 12202  ERX3126989           ID541          NextSeq 500        PAIRED
# 12203  ERX2067876  SAMEA104124589       Illumina MiSeq        PAIRED
# 12204   SRX349517      Ef_aus0081  Illumina HiSeq 2000        PAIRED
#
#          libraryselection librarysource  ...       biosample  \
# 0      size fractionation       GENOMIC  ...    SAMN09685496
# 1      size fractionation       GENOMIC  ...    SAMN09685602
# 2                  RANDOM       GENOMIC  ...    SAMN08026603
# 3             unspecified       GENOMIC  ...    SAMN11026203
# 4             unspecified       GENOMIC  ...    SAMN11026145
# ...                   ...           ...  ...             ...
# 12200              RANDOM       GENOMIC  ...    SAMN03359107
# 12201              RANDOM       GENOMIC  ...    SAMN03359111
# 12202         unspecified       GENOMIC  ...    SAMEA5224408
# 12203         unspecified       GENOMIC  ...  SAMEA104124589
# 12204  size fractionation       GENOMIC  ...    SAMN02318182
#
#                               organism  sra_study              releasedate  \
# 0                Enterococcus faecalis  SRP156712  2019-01-15 00:00:00 UTC
# 1                Enterococcus faecalis  SRP156712  2019-01-15 00:00:00 UTC
# 2                Enterococcus faecalis  SRP124977  2018-10-01 00:00:00 UTC
# 3                Enterococcus faecalis  SRP187019  2019-02-27 00:00:00 UTC
# 4                 Enterococcus faecium  SRP187019  2019-02-27 00:00:00 UTC
# ...                                ...        ...                      ...
# 12200            Enterococcus faecalis  SRP022914  2016-02-24 00:00:00 UTC
# 12201            Enterococcus faecalis  SRP022914  2016-02-24 00:00:00 UTC
# 12202             Enterococcus faecium  ERP113251  2019-02-08 00:00:00 UTC
# 12203            Enterococcus faecalis  ERP023530  2017-06-21 00:00:00 UTC
# 12204  Enterococcus faecium Ef_aus0081  SRP029918  2013-12-11 00:00:00 UTC
#
#         bioproject mbytes avgspotlen  mbases  insertsize    library_name
# 0      PRJNA481658   1531        602    2518         NaN       lib150453
# 1      PRJNA481658    354        478     640         NaN            2455
# 2      PRJNA418345    588        288    1390         NaN   WGS Day 1 WT3
# 3      PRJNA524396    119        288     256         NaN              60
# 4      PRJNA524396    311        286     611         NaN               2
# ...            ...    ...        ...     ...         ...             ...
# 12200  PRJNA203445    241        200     381         NaN        BCW_3740
# 12201  PRJNA203445    140        200     222         NaN        BCW_3745
# 12202   PRJEB30772    217        300     462       550.0     unspecified
# 12203   PRJEB21295     69        264     130       500.0     unspecified
# 12204  PRJNA205886   1086        200    1658         NaN  lib-Ef_aus0081
#
# [12205 rows x 22 columns]

# %%
meta.describe()
# Out:
#              mbytes    avgspotlen        mbases   insertsize
# count  12205.000000  12205.000000  12205.000000  9791.000000
# mean     201.198034    302.646456    408.505449   366.136656
# std      214.936021     94.258125    358.560727   219.698931
# min       21.000000     93.000000     56.000000    75.000000
# 25%      104.000000    250.000000    257.000000   150.000000
# 50%      160.000000    296.000000    343.000000   372.000000
# 75%      232.000000    302.000000    454.000000   500.000000
# max     4112.000000    602.000000   6633.000000  3000.000000

# %%
from matplotlib import pyplot as plt

# %%
import bigquery

# %%
meta.plot(kind='scatter',x='avgspotlen',y='insertsize',color='red')

# %%
import seaborn as sns

# %%
sns.pairplot(meta)
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
meta.head()
# Out:
#           acc assay_type                    center_name consent  experiment  \
# 0  SRR7658778        WGS          ROBERT KOCH INSTITUTE  public  SRX4520536
# 1  SRR7658860        WGS          ROBERT KOCH INSTITUTE  public  SRX4520454
# 2  SRR6291251        WGS  UNIVERSITY OF TEXAS AT DALLAS  public  SRX3392346
# 3  SRR8643180        WGS             MURDOCH UNIVERSITY  public  SRX5441529
# 4  SRR8643250        WGS             MURDOCH UNIVERSITY  public  SRX5441459
#
#      sample_name           instrument librarylayout    libraryselection  \
# 0         UW1485  Illumina HiSeq 2500        PAIRED  size fractionation
# 1        UW14000       Illumina MiSeq        PAIRED  size fractionation
# 2  WGS Day 1 WT3  Illumina HiSeq 2500        PAIRED              RANDOM
# 3           DBC3          NextSeq 500        PAIRED         unspecified
# 4           AAB2          NextSeq 500        PAIRED         unspecified
#
#   librarysource  ...     biosample               organism  sra_study  \
# 0       GENOMIC  ...  SAMN09685496  Enterococcus faecalis  SRP156712
# 1       GENOMIC  ...  SAMN09685602  Enterococcus faecalis  SRP156712
# 2       GENOMIC  ...  SAMN08026603  Enterococcus faecalis  SRP124977
# 3       GENOMIC  ...  SAMN11026203  Enterococcus faecalis  SRP187019
# 4       GENOMIC  ...  SAMN11026145   Enterococcus faecium  SRP187019
#
#                releasedate   bioproject mbytes avgspotlen  mbases  insertsize  \
# 0  2019-01-15 00:00:00 UTC  PRJNA481658   1531        602    2518         NaN
# 1  2019-01-15 00:00:00 UTC  PRJNA481658    354        478     640         NaN
# 2  2018-10-01 00:00:00 UTC  PRJNA418345    588        288    1390         NaN
# 3  2019-02-27 00:00:00 UTC  PRJNA524396    119        288     256         NaN
# 4  2019-02-27 00:00:00 UTC  PRJNA524396    311        286     611         NaN
#
#     library_name
# 0      lib150453
# 1           2455
# 2  WGS Day 1 WT3
# 3             60
# 4              2
#
# [5 rows x 22 columns]

# %%
from collections import Counter

# %%
Counter(meta["instrument"])
# Out:
# Counter({'Illumina HiSeq 2500': 581,
#          'Illumina MiSeq': 3765,
#          'NextSeq 500': 3091,
#          'Illumina HiSeq 2000': 4006,
#          'unspecified': 98,
#          'HiSeq X Ten': 652,
#          'Illumina Genome Analyzer II': 9,
#          'Illumina HiSeq 1500': 1,
#          'Illumina HiScanSQ': 1,
#          'Illumina Genome Analyzer': 1})

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-3-490cf645c3eb> in <module>
# ----> 1 client = bigquery.Client()
#
# /usr/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info)
#     165     ):
#     166         super(Client, self).__init__(
# --> 167             project=project, credentials=credentials, _http=_http
#     168         )
#     169         self._connection = Connection(self, client_info=client_info)
#
# /usr/local/lib/python3.7/site-packages/google/cloud/client.py in __init__(self, project, credentials, _http)
#     224
#     225     def __init__(self, project=None, credentials=None, _http=None):
# --> 226         _ClientProjectMixin.__init__(self, project=project)
#     227         Client.__init__(self, credentials=credentials, _http=_http)
#
# /usr/local/lib/python3.7/site-packages/google/cloud/client.py in __init__(self, project)
#     176
#     177     def __init__(self, project=None):
# --> 178         project = self._determine_default(project)
#     179         if project is None:
#     180             raise EnvironmentError(
#
# /usr/local/lib/python3.7/site-packages/google/cloud/client.py in _determine_default(project)
#     191     def _determine_default(project):
#     192         """Helper:  use default project detection."""
# --> 193         return _determine_default_project(project)
#     194
#     195
#
# /usr/local/lib/python3.7/site-packages/google/cloud/_helpers.py in _determine_default_project(project)
#     184     """
#     185     if project is None:
# --> 186         _, project = google.auth.default()
#     187     return project
#     188
#
# /usr/local/lib/python3.7/site-packages/google/auth/_default.py in default(scopes, request)
#     315             return credentials, effective_project_id
#     316
# --> 317     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %%
print("hi")
# Out:
# hi
